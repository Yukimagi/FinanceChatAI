# %%
#(先將剛剛下載的Python套件import進來)
import requests
from bs4 import BeautifulSoup

# %%
#將網頁Get下來
r = requests.get("https://www.ptt.cc/bbs/MobileComm/index.html") #將此頁面的HTML GET下來
print(r.text) #印出HTML
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 MobileComm 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/MobileComm/index.html"><span class="board-label">看板 </span>MobileComm</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/MobileComm/index.html">看板</a>
# 				<a class="btn" href="/man/MobileComm/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/MobileComm/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/MobileComm/index6845.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/MobileComm/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1691548872.A.0CC.html">Re: [討論] 為什麼覺得亞太台星被合併網路會變好？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ULTIMA1002</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D&#43;%E7%82%BA%E4%BB%80%E9%BA%BC%E8%A6%BA%E5%BE%97%E4%BA%9E%E5%A4%AA%E5%8F%B0%E6%98%9F%E8%A2%AB%E5%90%88%E4%BD%B5%E7%B6%B2%E8%B7%AF%E6%9C%83%E8%AE%8A%E5%A5%BD%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3AULTIMA1002">搜尋看板內 ULTIMA1002 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">52</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1691550603.A.158.html">[購機] S23U、Sony 1 V、小米13pro</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">julian122333</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E8%B3%BC%E6%A9%9F%5D&#43;S23U%E3%80%81Sony&#43;1&#43;V%E3%80%81%E5%B0%8F%E7%B1%B313pro">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3Ajulian122333">搜尋看板內 julian122333 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">39</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1691550884.A.8D7.html">[討論] 日本五日遊網卡選擇(esim vs sim卡)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">HaiYan330</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D&#43;%E6%97%A5%E6%9C%AC%E4%BA%94%E6%97%A5%E9%81%8A%E7%B6%B2%E5%8D%A1%E9%81%B8%E6%93%87%28esim&#43;vs&#43;sim%E5%8D%A1%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3AHaiYan330">搜尋看板內 HaiYan330 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				(已被starskyjth刪除) &lt;jb1853&gt; 3-2
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">-</div>
# 				<div class="article-menu">
#
# 				</div>
# 				<div class="date"> 8/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">93</span></div>
# 			<div class="title">
#
# 				(已被starskyjth刪除) &lt;gaiaesque&gt; 1-1-O
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">-</div>
# 				<div class="article-menu">
#
# 				</div>
# 				<div class="date"> 8/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f0">X1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1691561865.A.CD2.html">Re: [新聞] 外媒：三星手機銷量全球第一 但利潤只有</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">asin404</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E5%A4%96%E5%AA%92%EF%BC%9A%E4%B8%89%E6%98%9F%E6%89%8B%E6%A9%9F%E9%8A%B7%E9%87%8F%E5%85%A8%E7%90%83%E7%AC%AC%E4%B8%80&#43;%E4%BD%86%E5%88%A9%E6%BD%A4%E5%8F%AA%E6%9C%89">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3Aasin404">搜尋看板內 asin404 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">8</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1691563975.A.7A5.html">Re: [新聞] 外媒：三星手機銷量全球第一 但利潤只有</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">magic543</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E5%A4%96%E5%AA%92%EF%BC%9A%E4%B8%89%E6%98%9F%E6%89%8B%E6%A9%9F%E9%8A%B7%E9%87%8F%E5%85%A8%E7%90%83%E7%AC%AC%E4%B8%80&#43;%E4%BD%86%E5%88%A9%E6%BD%A4%E5%8F%AA%E6%9C%89">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3Amagic543">搜尋看板內 magic543 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1691564669.A.BAF.html">[問題] Android特定通知修改鈴聲</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">t516</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E5%95%8F%E9%A1%8C%5D&#43;Android%E7%89%B9%E5%AE%9A%E9%80%9A%E7%9F%A5%E4%BF%AE%E6%94%B9%E9%88%B4%E8%81%B2">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3At516">搜尋看板內 t516 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">9</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1691565674.A.8DA.html">[問題] Pixel 6 pro/ Pixel 7 pro 美國ESIM</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">sandarac</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E5%95%8F%E9%A1%8C%5D&#43;Pixel&#43;6&#43;pro%2F&#43;Pixel&#43;7&#43;pro&#43;%E7%BE%8E%E5%9C%8BESIM">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3Asandarac">搜尋看板內 sandarac 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1691567044.A.0C5.html">Re: [新聞] 外媒：三星手機銷量全球第一 但利潤只有</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author
EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3Atkucwlin">搜尋看板內 tkucwlin 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/10</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1632715576.A.195.html">[公告] MobileComm板規</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ginlom</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;MobileComm%E6%9D%BF%E8%A6%8F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3Aginlom">搜尋看板內 ginlom 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 9/27</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">82</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1672502593.A.3CD.html">[專區] 置底閒聊區</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ginlom</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E5%B0%88%E5%8D%80%5D&#43;%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E5%8D%80">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3Aginlom">搜尋看板內 ginlom 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 1/01</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# </div>
#
#
#
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     <script defer src="https://static.cloudflareinsights.com/beacon.min.js/v8b253dfea2ab4077af8c6f58422dfbfd1689876627854" integrity="sha512-bjgnUKX4azu3dLTVtie9u6TKqgx29RBwfj3QXYt5EKfWM/9hPSAI/4qcV5NACjwAo8UtTeWefx6Zq5PHcMm7Tg==" data-cf-beacon='{"rayId":"7f4251d44ee1ef9a","version":"2023.7.0","r":1,"b":1,"token":"515615eb5fab4c9b91a11e9bf529e6cf","si":100}' crossorigin="anonymous"></script>
# </body>
# </html>

# %%
#將抓下來的資料用Beautifulsoup4轉為HTML的parser
soup = BeautifulSoup(r.text,"html.parser") #將網頁資料以html.parser
sel = soup.select("div.title a") #***取HTML標中的 <div class="title"></div> 中的<a>標籤存入sel

# %%
#最後寫一個迴圈將爬下來的文章標題印出來
for s in sel:
    print(s["href"], s.text)
# Out:
# /bbs/MobileComm/M.1691548872.A.0CC.html Re: [討論] 為什麼覺得亞太台星被合併網路會變好？
# /bbs/MobileComm/M.1691550603.A.158.html [購機] S23U、Sony 1 V、小米13pro
# /bbs/MobileComm/M.1691550884.A.8D7.html [討論] 日本五日遊網卡選擇(esim vs sim卡)
# /bbs/MobileComm/M.1691561865.A.CD2.html Re: [新聞] 外媒：三星手機銷量全球第一 但利潤只有
# /bbs/MobileComm/M.1691563975.A.7A5.html Re: [新聞] 外媒：三星手機銷量全球第一 但利潤只有
# /bbs/MobileComm/M.1691564669.A.BAF.html [問題] Android特定通知修改鈴聲
# /bbs/MobileComm/M.1691565674.A.8DA.html [問題] Pixel 6 pro/ Pixel 7 pro 美國ESIM
# /bbs/MobileComm/M.1691567044.A.0C5.html Re: [新聞] 外媒：三星手機銷量全球第一 但利潤只有
# /bbs/MobileComm/M.1691571770.A.5EE.html Re: [新聞] 外媒：三星手機銷量全球第一 但利潤只有
# /bbs/MobileComm/M.1691572302.A.BB2.html Re: [新聞] 外媒：三星手機銷量全球第一 但利潤只有
# /bbs/MobileComm/M.1691586646.A.568.html [新聞] 華為宣告下一代鴻蒙系統不再相容Android
# /bbs/MobileComm/M.1691587276.A.66A.html [問題] S23的超快速快充沒有真的超快速？
# /bbs/MobileComm/M.1691587852.A.9F3.html [問題] line上傳檔案顯示檔名
# /bbs/MobileComm/M.1691588450.A.C37.html [新聞] 谷歌申請“螢幕下鏡頭”專利，未來 Pixel
# /bbs/MobileComm/M.1691591891.A.22C.html [公告] 水桶
# /bbs/MobileComm/M.1691606282.A.325.html Re: [討論] 為什麼覺得亞太台星被合併網路會變好？
# /bbs/MobileComm/M.1632715576.A.195.html [公告] MobileComm板規
# /bbs/MobileComm/M.1672502593.A.3CD.html [專區] 置底閒聊區
