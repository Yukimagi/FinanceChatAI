# %%
#(先將剛剛下載的Python套件import進來)
import requests
from bs4 import BeautifulSoup

# %%
#將網頁Get下來
r = requests.get("https://www.crsp.org/main-menu/crsp-action") #將此頁面的HTML GET下來
print(r.text) #印出HTML
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML+RDFa 1.1//EN"
# "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd"><html lang="en" dir="ltr" version="HTML+RDFa 1.1"
#   xmlns:content="http://purl.org/rss/1.0/modules/content/"
#   xmlns:dc="http://purl.org/dc/terms/"
#   xmlns:foaf="http://xmlns.com/foaf/0.1/"
#   xmlns:og="http://ogp.me/ns#"
#   xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#   xmlns:sioc="http://rdfs.org/sioc/ns#"
#   xmlns:sioct="http://rdfs.org/sioc/types#"
#   xmlns:skos="http://www.w3.org/2004/02/skos/core#"
#   xmlns:xsd="http://www.w3.org/2001/XMLSchema#" class="no-js"><head profile="http://www.w3.org/1999/xhtml/vocab">
#
#   <meta charset="utf-8" />
# <meta name="Generator" content="Drupal 7 (http://drupal.org)" />
# <link rel="canonical" href="/main-menu/crsp-action" />
# <link rel="shortlink" href="/node/14" />
# <link rel="shortcut icon" href="https://www.crsp.org/sites/all/themes/crsp/favicon.ico" type="image/vnd.microsoft.icon" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
#
#   <title>CRSP In Action | CRSP - The Center for Research in Security Prices</title>
#
#   <style type="text/css" media="all">
# @import url("https://www.crsp.org/modules/system/system.base.css?rtdc9y");
# @import url("https://www.crsp.org/modules/system/system.menus.css?rtdc9y");
# @import url("https://www.crsp.org/modules/system/system.messages.css?rtdc9y");
# @import url("https://www.crsp.org/modules/system/system.theme.css?rtdc9y");
# @import url("https://www.crsp.org/sites/all/themes/sasson/styles/reset/normalize.css?rtdc9y");
# @import url("https://www.crsp.org/modules/book/book.css?rtdc9y");
# @import url("https://www.crsp.org/sites/all/modules/contrib/calendar/css/calendar_multiday.css?rtdc9y");
# @import url("https://www.crsp.org/modules/field/theme/field.css?rtdc9y");
# @import url("https://www.crsp.org/modules/node/node.css?rtdc9y");
# @import url("https://www.crsp.org/modules/search/search.css?rtdc9y");
# @import url("https://www.crsp.org/modules/user/user.css?rtdc9y");
# @import url("https://www.crsp.org/sites/all/modules/contrib/views/css/views.css?rtdc9y");
# @import url("https://www.crsp.org/sites/all/modules/contrib/ckeditor/css/ckeditor.css?rtdc9y");
# </style>
# <style type="text/css" media="all">
# @import url("https://www.crsp.org/files/css/sasson.css?rtdc9y");
# @import url("https://www.crsp.org/sites/all/modules/contrib/ctools/css/ctools.css?rtdc9y");
# @import url("https://www.crsp.org/sites/all/modules/contrib/panels/css/panels.css?rtdc9y");
# @import url("https://www.crsp.org/sites/all/modules/widgets/widgets.css?rtdc9y");
# @import url("https://www.crsp.org/sites/all/modules/responsive_dropdown_menus/theme/responsive-dropdown-menus.css?rtdc9y");
# @import url("https://www.crsp.org/files/css/crsp-html.css?rtdc9y");
# @import url("https://www.crsp.org/files/css/crsp.css?rtdc9y");
# @import url("https://www.crsp.org/sites/all/themes/crsp/styles/jquery.ui.theme.css?rtdc9y");
# @import url("https://www.crsp.org/sites/all/themes/crsp/styles/jquery.ui.tabs.css?rtdc9y");
# </style>
# <style type="text/css" media="print">
# @import url("https://www.crsp.org/files/css/print.css?rtdc9y");
# </style>
#
# <!--[if lte IE 8]>
# <style type="text/css" media="all">
# @import url("https://www.crsp.org/files/css/ie8.css?rtdc9y");
# </style>
# <![endif]-->
#
# <!--[if lte IE 7]>
# <style type="text/css" media="all">
# @import url("https://www.crsp.org/files/css/ie7.css?rtdc9y");
# </style>
# <![endif]-->
#   <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0];var j=d.createElement(s);var dl=l!='dataLayer'?'&l='+l:'';j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl+'';j.async=true;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-WQTM3DS');
# //--><!]]>
# </script>
# <script type="text/javascript" src="https://www.crsp.org/files/js/js_YD9ro0PAqY25gGWrTki6TjRUG8TdokmmxjfqpNNfzVU.js"></script>
# <script type="text/javascript" src="https://www.crsp.org/files/js/js_fnFMT3X1_bhCDaBABvWwi8Yq5Useb8r_XorbufldYMA.js"></script>
# <script type="text/javascript" src="https://www.crsp.org/files/js/js_6BG5e4flEAMDyinnTOlVGecZ5egGM3zZQNQiH0wGnD0.js"></script>
# <script type="text/javascript" src="https://www.crsp.org/files/js/js_yJ4u0pU8P3EWGwf1YRvauDOCkWG2bEIfBZKIAFIhYFE.js"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","setHasJsCookie":0,"ajaxPageState":{"theme":"crsp","theme_token":"EW6yNHT7wXQ4Q15XmvDrsQH3xq8brJpmpvuC48hzNsQ","js":{"0":1,"misc\/jquery.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/beautytips\/js\/jquery.bt.min.js":1,"sites\/all\/modules\/beautytips\/js\/beautytips.min.js":1,"sites\/all\/modules\/responsive_dropdown_menus\/theme\/responsive-dropdown-menus.js":1,"sites\/all\/themes\/sasson\/scripts\/sasson.js":1,"sites\/all\/themes\/crsp\/scripts\/jquery.equalheights.js":1,"sites\/all\/themes\/crsp\/scripts\/crsp.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"sites\/all\/themes\/sasson\/styles\/reset\/normalize.css":1,"modules\/book\/book.css":1,"sites\/all\/modules\/contrib\/calendar\/css\/calendar_multiday.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/themes\/sasson\/styles\/sasson.scss":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/contrib\/panels\/css\/panels.css":1,"sites\/all\/modules\/widgets\/widgets.css":1,"sites\/all\/modules\/responsive_dropdown_menus\/theme\/responsive-dropdown-menus.css":1,"sites\/all\/themes\/crsp\/styles\/crsp-html.scss":1,"sites\/all\/themes\/crsp\/styles\/crsp.scss":1,"sites\/all\/themes\/crsp\/styles\/jquery.ui.theme.css":1,"sites\/all\/themes\/crsp\/styles\/jquery.ui.tabs.css":1,"sites\/all\/themes\/crsp\/styles\/print.scss":1,"sites\/all\/themes\/crsp\/styles\/ie8.scss":1,"sites\/all\/themes\/crsp\/styles\/ie7.scss":1}},"beautytipStyles":{"default":{"fill":"#F4F4F4","strokeStyle":"#666666","spikeLength":20,"spikeGirth":10,"width":350,"overlap":0,"centerPointY":1,"cornerRadius":0,"cssStyles":{"fontFamily":"\u0026quot;Lucida Grande\u0026quot;,Helvetica,Arial,Verdana,sans-serif","fontSize":"12px","padding":"10px 14px"},"shadow":"1","shadowColor":"rgba(0,0,0,.5)","shadowBlur":8,"shadowOffsetX":4,"shadowOffsetY":4},"plain":[],"netflix":{"positions":["right","left"],"fill":"#FFF","padding":5,"shadow":true,"shadowBlur":12,"strokeStyle":"#B9090B","spikeLength":50,"spikeGirth":60,"cornerRadius":10,"centerPointY":0.10000000000000001,"overlap":-8,"cssStyles":{"fontSize":"12px","fontFamily":"arial,helvetica,sans-serif"}},"facebook":{"fill":"#F7F7F7","padding":8,"strokeStyle":"#B7B7B7","cornerRadius":0,"cssStyles":{"fontFamily":"\u0022lucida grande\u0022,tahoma,verdana,arial,sans-serif","fontSize":"11px"}},"transparent":{"fill":"rgba(0, 0, 0, .8)","padding":20,"strokeStyle":"#CC0","strokeWidth":3,"spikeLength":40,"spikeGirth":40,"cornerRadius":40,"cssStyles":{"color":"#FFF","fontWeight":"bold"}},"big-green":{"fill":"#00FF4E","padding":20,"strokeWidth":0,"spikeLength":40,"spikeGirth":40,"cornerRadius":15,"cssStyles":{"fontFamily":"\u0022lucida grande\u0022,tahoma,verdana,arial,sans-serif","fontSize":"14px"}},"google-maps":{"positions":["top","bottom"],"fill":"#FFF","padding":15,"strokeStyle":"#ABABAB","strokeWidth":1,"spikeLength":65,"spikeGirth":40,"cornerRadius":25,"centerPointX":0.90000000000000002,"cssStyles":[]},"hulu":{"fill":"#F4F4F4","strokeStyle":"#666666","spikeLength":20,"spikeGirth":10,"width":350,"overlap":0,"centerPointY":1,"cornerRadius":0,"cssStyles":{"fontFamily":"\u0022Lucida Grande\u0022,Helvetica,Arial,Verdana,sans-serif","fontSize":"12px","padding":"10px 14px"},"shadow":true,"shadowColor":"rgba(0,0,0,.5)","shadowBlur":8,"shadowOffsetX":4,"shadowOffsetY":4}},"beautytips":{"beautytips_manager_custom_1":{"cssSelect":"#edit-submitted-usage-3","style":"hulu","trigger":"hover","shrinkToFit":false,"ajaxDisableLink":false,"text":"\u003Cp\u003ECRSP is p ...
# //--><!]]>
# </script>
#
#     <!--[if lt IE 9]><script src="/sites/all/themes/sasson/scripts/html5shiv.js"></script><![endif]--><script type="text/javascript" src="https://fast.fonts.net/jsapi/4a260fdd-810a-481a-bdeb-b94375e843ae.js"></script>
# <META HTTP-EQUIV="Content-type" CONTENT="text/html; charset=UTF-8">
# <script src="https://www.google.com/recaptcha/api.js"></script>
# <script>
#  function timestamp() { var response = document.getElementById("g-recaptcha-response"); if (response == null || response.value.trim() == "") {var elems = JSON.parse(document.getElementsByName("captcha_settings")[0].value);elems["ts"] = JSON.stringify(new Date().getTime());document.getElementsByName("captcha_settings")[0].value = JSON.stringify(elems); } } setInterval(timestamp, 500);
# </script>
# </head>
# <body class="html not-front not-logged-in no-sidebars page-node page-node- page-node-14 node-type-page with-navigation dir-ltr page-crsp-action section-main-menu" >
#
#
#     <div class="region region-page-top">
#     <noscript aria-hidden="true"><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WQTM3DS" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#   </div>
#
# <div id="page">
#
#       <header id="header" role="banner">
#         <div class="bounds">
#
#               <a href="/" title="Home" rel="home" id="logo">
#           <img src="https://www.crsp.org/files/crsp-llc-logo-web-01_3.png" alt="Home" />
#         </a>
#
#         <div class="region region-header">
#     <div id="block-block-9" class="block block-block block-odd">
#
#
#   <div class="content">
#     <p><a href="/form/subscription-information-request"><img src="https://www.crsp.org/files/images/arrow-new.png">&nbsp;Subscription Information</a></p>
#   </div><!-- /.content -->
#
# </div><!-- /.block -->
# <div id="block-search-form" class="block block-search block-even">
#
#
#   <div class="content">
#     <form action="/main-menu/crsp-action" method="post" id="search-block-form" accept-charset="UTF-8"><div><div class="container-inline">
#       <h2 class="element-invisible">Search form</h2>
#     <div class="form-item form-type-textfield form-item-search-block-form">
#   <label for="edit-search-block-form--2">Search </label>
#  <input title="Enter the terms you wish to search for." type="search" id="edit-search-block-form--2" name="search_block_form" value="" size="15" maxlength="128" class="form-text" />
# </div>
# <div class="form-actions form-wrapper" id="edit-actions"><input type="submit" id="edit-submit" name="op" value="Search" class="form-submit" /></div><input type="hidden" name="form_build_id" value="form-_SIA0r90WLUxNVuS6xpk4MFfk6NhangMoclQAEzgi5c" />
# <input type="hidden" name="form_id" value="search_block_form" />
# </div>
# </div></form>  </div><!-- /.content -->
#
# </div><!-- /.block -->
# <div id="block-widgets-s-socialmedia-profile-default" class="block block-widgets block-odd">
#
#
#   <div class="content">
#     <div id="widgets-element-socialmedia_profile-default" class="widgets widgets-set widgets-set-horizontal widgets-style-horizontal"><div id="widgets-element-socialmedia_socialmedia-twitter-profile-button" class="widgets widgets-element widgets-element-horizontal widgets-style-horizontal"><a href="http://twitter.com/CRSPData" title="Visit CRSPData on Twitter" target="_blank"><img src="/sites/all/modules/socialmedia/icons/levelten/glossy/16x16/twitter.png" alt="Twitter icon" ></a></div><div id="widgets-element-socialmedia_socialmedia-linkedin-profile-button" class="widgets widgets-element widgets-element-horizontal widgets-style-horizontal"><a href="http://www.linkedin.com/company/center-for-research-in-security-prices-crsp" title="Visit CRSP on LinkedIn" target="_blank"><img src="/sites/all/modules/socialmedia/icons/levelten/glossy/16x16/linkedin.png" alt="LinkedIn icon" ></a></div><div class="widgets-clear"></div></div>  </div><!-- /.content -->
#
# </div><!-- /.block -->
#   </div>
#         </div><!-- /bounds -->
#     </header><!-- /#header -->
#
#       <nav id="main-menu" role="navigation">
#         <div class="bounds">
#           <div class="inner">
#             <ul id="main-menu" class="main-menu responsive-menu links"><li id="menu-item-3560" class="menu-item menu-item-primary first"><a href="/main-menu/about-crsp">About CRSP</a></li>
# <li id="menu-item-2602" class="menu-item menu-parent menu-item-primary"><a title="" class="nolink" tabindex="0">Products</a><ul class="sub-menu tier-two"><li id="menu-item-2603" class="menu-item menu-item-secondary first"><a href="/products/investment-products">Investment Products</a></li>
# <li id="menu-item-2604" class="menu-item menu-item-secondary last"><a href="/products/research-products">Research Products</a></li>
# </ul></li>
# <li id="menu-item-2605" class="menu-item menu-item-primary"><a href="/documentation" title="">Documentation</a></li>
# <li id="menu-item-580" class="menu-item active-trail active menu-item-primary"><a href="/main-menu/crsp-action" class="active">CRSP In Action</a></li>
# <li id="menu-item-3558" class="menu-item menu-item-primary"><a href="/main-menu/careers">Careers</a></li>
# <li id="menu-item-3559" class="menu-item menu-item-primary last"><a href="/main-menu/contact-us">Contact Us</a></li>
# </ul>          </div><!-- /inner -->
#         </div><!-- /bounds -->
#     </nav><!-- /#main-menu -->
#
#
#
# <!--#wrap-->
# <div id="wrap">
#
#   <div id="main">
#
#               <h1 class="title" id="page-title">CRSP In Action</h1>
#                   <div class="tabs"></div>
#
#           <div class="region region-content">
#     <div id="block-system-main" class="block block-system block-even">
#
#
#   <div class="content">
#     <div  about="/main-menu/crsp-action" typeof="foaf:Document" class="ds-1col node node-page node-teaser node-even published with-comments node-teaser view-mode-teaser clearfix">
#
#
#   <div class="field field-name-body"><div style="width: 535px; height: 285px; vertical-align: middle; padding: 30px 45px 45px 360px; background-color: #006a9e; background-image: url(../files/CIA_Page_Header_medium_blue2.png);">
# 	<h2>
# 		<span style="color:#ffffff;">Monthly reports summarizing our indexes data performance and citations in research papers:</span></h2>
# 	<p style="margin-top:10px"><span style="color: rgb(255, 255, 255);"><strong>2023</strong></span><br />
# 		<a href="http://crsp.org/files/CRSP_Market_Update_-_January_2023.pdf"><span style="color: rgb(255, 255, 255);">January&nbsp;</span></a><span style="color: rgb(255, 255, 255);">|&nbsp;</span><a href="http://crsp.org/files/CRSP_Market_Update_-_February_2023.pdf"><span style="color: rgb(255, 255, 255);">February&nbsp;</span></a><span style="color: rgb(255, 255, 255);">|&nbsp;</span><a href="http://crsp.org/files/CRSP_Market_Update_-_March_2023.pdf"><span style="color: rgb(255, 255, 255);">March</span></a><a href="http://crsp.org/files/CRSP_Market_Update_-_February_2023.pdf"><span style="color: rgb(255, 255, 255);">&nbsp;</span></a><span style="color: rgb(255, 255, 255);">|&nbsp;</span><a href="/files/CRSP_Market_Update_-_April_2023.pdf"><span style="color: rgb(255, 255, 255);">April</span></a>&nbsp;<span style="color: rgb(255, 255, 255);">|&nbsp;</span><a href="/files/CRSP_Market_Update_-_May_2023.pdf"><span style="color: rgb(255, 255, 255);">May</span></a>&nbsp;<span style="color: rgb(255, 255, 255);">|&nbsp;</span><a href="/files/CRSP_Market_Update_-_June_2023.pdf"><span style="color: rgb(255, 255, 255);">June</span></a><br />
# 		<span style="color:#ffffff;"><strong>2022</strong></span><br />
# 		<a href="http://crsp.org/files/CRSP_Market_Update_-_January_2022.pdf"><span style="color:#ffffff;">January </span></a><span style="color:#ffffff;">| </span><a href="http://crsp.org/files/CRSP_Market_Update_-_February_2022.pdf"><span style="color:#ffffff;">February </span></a><span style="color:#ffffff;">| </span><a href="http://crsp.org/files/CRSP_Market_Update_-_March_2022.pdf"><span style="color:#ffffff;">March </span></a><span style="color:#ffffff;">| </span><a href="http://crsp.org/files/CRSP_Market_Update_-_April_2022.pdf"><span style="color:#ffffff;">April</span></a>&nbsp;<span style="color:#ffffff;">|</span> <a href="http://crsp.org/files/CRSP_Market_Update_-_May_2022.pdf"><span style="color:#ffffff;">May</span></a>&nbsp;<span style="color:#ffffff;">|</span>&nbsp;<a href="/files/CRSP_Market_Update_-_June_2022.pdf"><font color="#ffffff">June</font></a>&nbsp;<span style="color:#ffffff;">|</span>&nbsp;<a href="/files/CRSP_Market_Update_-_July_2022.pdf"><font color="#ffffff">July</font></a>&nbsp;<br />
# 		<a href="/files/CRSP_Market_Update_-_August_2022.pdf"><font color="#ffffff">August</font></a>&nbsp;<span style="color:#ffffff;">|</span>&nbsp;<a href="/files/CRSP_Market_Update_-_September_2022.pdf"><font color="#ffffff">September</font></a>&nbsp;<span style="color: rgb(255, 255, 255);">|</span>&nbsp;<a href="/files/CRSP_Market_Update_-_October_2022.pdf" style="color: rgb(179, 201, 222); outline: 0px;"><font color="#ffffff">October</font></a>&nbsp;<span style="color: rgb(255, 255, 255);">|</span>&nbsp;<a href="/files/CRSP_Market_Update_-_November_2022.pdf" style="color: rgb(179, 201, 222); outline: 0px;"><font color="#ffffff">November</font></a>&nbsp;<span style="color: rgb(255, 255, 255);">|</span>&nbsp;<a href="/files/CRSP_Market_Update_-_December_2022.pdf" style="color: rgb(179, 201, 222); outline: 0px;"><font color="#ffffff">December</font></a><br />
# 		<span style="color:#ffffff; margin-top:10px;"><strong>2021</strong></span><br />
# 		<a href="http://crsp.org/files/CRSP_Market_Update_-_Janaury_2021.pdf"><span style="color:#ffffff;">January </span></a><span style="color:#ffffff;">| </span><a href="http://crsp.org/files/CRSP_Market_Update_-_February_2021.pdf"><span style="color:#ffffff;">February </span></a><span style="color:#ffffff;">| </span><a href="http://crsp.org/files/CRSP_Market_Update_-_March_2021.pdf"><span style="color:#ffffff;">March </span></a><span style="color:#ffffff;">| </span><a href="http://crsp.org/files/CRSP_Market_Update_-_April_2021.pdf"><span style="color:#ffffff;">April </span></a><span style="color:#ffffff;">| </span><a href="http://crsp.org/files/CRSP_Market_Update_-_May_2021.pdf"><span style="color:#ffffff;">May </span></a><span style="color:#ffffff;">| </span><a href="http://crsp.org/files/CRSP_Market_Update_-_June_2021.pdf"><span style="color:#ffffff;">June </span></a><span style="color:#ffffff;">| </span><a href="http://crsp.org/files/CRSP_Market_Update_-_July_2021.pdf"><span style="color:#ffffff;">July</span></a><br />
# 		<a href="http://crsp.org/files/CRSP_Market_Update_-_August_2021.pdf"><span style="color:#ffffff;">August </span></a><span style="color:#ffffff;">| </span><a href="http://crsp.org/files/CRSP_Market_Update_-_September_2021.pdf"><span style="color:#ffffff;">September </span></a><span style="color:#ffffff;">| </span><a href="http://crsp.org/files/CRSP_Market_Update_-_October_2021.pdf"><span style="color:#ffffff;">October </span></a><span style="color:#ffffff;">| </span><a href="http://crsp.org/files/CRSP_Market_Update_-_November_2021.pdf"><span style="color:#ffffff;">November </span></a><span style="color:#ffffff;">| </span><a href="http://crsp.org/files/CRSP_Market_Update_-_December_2021.pdf"><span style="color:#ffffff;">December</span></a></p>
# </div>
# <p>&nbsp;</p>
# </div><div class="view view-latest-in-action-items view-id-latest_in_action_items view-display-id-entity_view_1 view-dom-id-00d827ca2bdf9b44892e5237974f7797">
#         <h2 class="title">CRSP in the News</h2>
#
#
#
#
#       <div class="view-content">
#       <div class="group-wrap group-count-1">
#   <div class="views-row views-row-1 views-row-odd views-row-first">
#     <div class="ds-1col node node-article node-teaser node-odd published no-comments node-teaser view-mode-teaser clearfix">
#
#
#   <h3><a href="https://news.uchicago.edu/story/douglas-diamond-2022-nobel-prize-economics">Douglas Diamond wins Nobel Prize for research on banks and financial crises</a></h3><div class="field field-name-body"><p><a href="https://news.uchicago.edu/story/douglas-diamond-2022-nobel-prize-economics"><img alt="" src="/files/douglas_diamond.jpg" style="width: 201px; height: 113px;" /></a></p>
# <p>Douglas W. Diamond, professor of the University of Chicago and longtime member of the CRSP Advisory Board, has been awarded the Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel 2022.</p>
# </div><div class="field field-name-custom-readmore"><div class="field-name-node-link"><a href="https://news.uchicago.edu/story/douglas-diamond-2022-nobel-prize-economics">Read More</a></div></div></div>
#
#   </div>
#   <div class="views-row views-row-2 views-row-even">
#     <div class="ds-1col node node-article node-teaser node-even published no-comments node-teaser view-mode-teaser clearfix">
#
#
#   <h3><a href="https://cboe-1.wistia.com/medias/8uzjk45ifr">CBOT Closing Bell Ceremony - September 12</a></h3><div class="field field-name-body"><p><a href="https://cboe-1.wistia.com/medias/8uzjk45ifr"><img alt="" src="data:image/png;base64,..." style="height: 112px; width: 200px;" /></a></p>
# <p>CRSP CEO David Barclay was invited to participate in the closing bell ceremony at CBOT in Chicago on September 12 in recognition of the Index Industry Association&rsquo;s 10th year.</p>
# </div><div class="field field-name-custom-readmore"><div class="field-name-node-link"><a href="https://cboe-1.wistia.com/medias/8uzjk45ifr">Read More</a></div></div></div>
#
#   </div>
#   <div class="views-row views-row-3 views-row-odd">
#     <div class="ds-1col node node-research-item node-teaser node-odd published no-comments node-teaser view-mode-teaser clearfix">
#
#
#   <h3><a href="https://www.morningstar.com/articles/1095120/why-vanguard-value-index-is-a-good-investment-today">Why Vanguard Value Index Is a Good Investment Today</a></h3><div class="field field-name-field-publication">Morningstar</div><div class="field field-name-body"><p><span style="color: rgba(0, 0, 0, 0.9); font-family: -apple-system, system-ui, BlinkMacSystemFont, &quot;Segoe UI&quot;, Roboto, &quot;Helvetica Neue&quot;, &quot;Fira Sans&quot;, Ubuntu, Oxygen, &quot;Oxygen Sans&quot;, Cantarell, &quot;Droid Sans&quot;, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Symbol&quot;, &quot;Lucida Grande&quot;, Helvetica, Arial, sans-serif; font-size: 14px;">According to&nbsp;</span><a data-attribute-index="0" data-entity-hovercard-id="urn:li:fs_miniCompany:5161" data-entity-type="MINI_COMPANY" href="https://www.linkedin.com/company/morningstar/" style="box-sizing: inherit; margin: var(--artdeco-reset-base-margin-zero); padding: var(--artdeco-reset-base-padding-zero); font-size: 14px; vertical-align: var(--artdeco-reset-base-vertical-align-baseline); text-decoration: var(--artdeco-reset-link-text-decoration-none); font-weight: var(--font-weight-bold); border: var(--artdeco-reset-link-border-zero); color: var(--color-action); touch-action: manipulation; position: relative; font-family: -apple-system, system-ui, BlinkMacSystemFont, &quot;Segoe UI&quot;, Roboto, &quot;Helvetica Neue&quot;, &quot;Fira Sans&quot;, Ubuntu, Oxygen, &quot;Oxygen Sans&quot;, Cantarell, &quot;Droid Sans&quot;, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Symbol&quot;, &quot;Lucida Grande&quot;, Helvetica, Arial, sans-serif; line-height: inherit !important;">Morningstar</a><span style="color: rgba(0, 0, 0, 0.9); font-family: -apple-system, system-ui, BlinkMacSystemFont, &quot;Segoe UI&quot;, Roboto, &quot;Helvetica Neue&quot;, &quot;Fira Sans&quot;, Ubuntu, Oxygen, &quot;Oxygen Sans&quot;, Cantarell, &quot;Droid Sans&quot;, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Symbol&quot;, &quot;Lucida Grande&quot;, Helvetica, Arial, sans-serif; font-size: 14px;">, &ldquo;</span><a data-attribute-index="2" data-entity-hovercard-id="urn:li:fs_miniCompany:3184" data-entity-type="MINI_COMPANY" href="https://www.linkedin.com/company/vanguard/" style="box-sizing: inherit; margin: var(--artdeco-reset-base-margin-zero); padding: var(--artdeco-reset-base-padding-zero); font-size: 14px; vertical-align: var(--artdeco-reset-base-vertical-align-baseline); text-decoration: var(--artdeco-reset-link-text-decoration-none); font-weight: var(--font-weight-bold); border: var(--artdeco-reset-link-border-zero); color: var(--color-action); touch-action: manipulation; position: relative; font-family: -apple-system, system-ui, BlinkMacSystemFont, &quot;Segoe UI&quot;, Roboto, &quot;Helvetica Neue&quot;, &quot;Fira Sans&quot;, Ubuntu, Oxygen, &quot;Oxygen Sans&quot;, Cantarell, &quot;Droid Sans&quot;, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Symbol&quot;, &quot;Lucida Grande&quot;, Helvetica, Arial, sans-serif; line-height: inherit !important;">Vanguard</a><span style="color: rgba(0, 0, 0, 0.9); font-family: -apple-system, system-ui, BlinkMacSystemFont, &quot;Segoe UI&quot;, Roboto, &quot;Helvetica Neue&quot;, &quot;Fira Sans&quot;, Ubuntu, Oxygen, &quot;Oxygen Sans&quot;, Cantarell, &quot;Droid Sans&quot;, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Symbol&quot;, &quot;Lucida Grande&quot;, Helvetica, Arial, sans-serif; font-size: 14px;">&nbsp;Value Index&#39;s (VVIAX) broadly diversified portfolio, low turnover, and pronounced cost advantage make it one of the best large-value funds available.&rdquo;</span></p>
# </div><div class="field field-name-custom-readmore"><div class="field-name-node-link"><a href="https://www.morningstar.com/articles/1095120/why-vanguard-value-index-is-a-good-investment-today">Read More</a></div></div></div>
#
#   </div>
#   <div class="views-row views-row-4 views-row-even">
#     <div class="ds-1col node node-article node-teaser node-even published no-comments node-teaser view-mode-teaser clearfix">
#
#
#   <h3><a href="https://www.bankrate.com/investing/best-value-etfs/">Best value ETFs</a></h3><div class="field field-name-field-byline">Bankrate</div><div class="field field-name-body"><p>The Vanguard Value ETF seeks to track the performance of the CRSP U.S. Large Cap Value Index, which measures the returns of large-cap value stocks. The fund holds about 350 different stocks.</p>
# </div><div class="field field-name-custom-readmore"><div class="field-name-node-link"><a href="https://www.bankrate.com/investing/best-value-etfs/">Read More</a></div></div></div>
#
#   </div>
#   <div class="views-row views-row-5 views-row-odd">
#     <div class="ds-1col node node-article node-teaser node-odd published no-comments node-teaser view-mode-teaser clearfix">
#
#
#   <h3><a href="https://www.ft.com/content/f916d132-0f86-4e0e-a3fa-6a80fdf6e40c">Passive ETFS Hit by Billion-Dollar Rebalancing Costs</a></h3><div class="field field-name-field-byline">Financial Times</div><div class="field field-name-body"><p>Research shows US index trackers lose out on nearly $4bn a year due to price moves created by front-running.</p>
# </div><div class="field field-name-custom-readmore"><div class="field-name-node-link"><a href="https://www.ft.com/content/f916d132-0f86-4e0e-a3fa-6a80fdf6e40c">Read More</a></div></div></div>
#
#   </div>
#   <div class="views-row views-row-6 views-row-even">
#     <div class="ds-1col node node-article node-teaser node-even published no-comments node-teaser view-mode-teaser clearfix">
#
#
#   <h3><a href="https://www.wsj.com/articles/mutual-funds-that-ate-wall-st-11638390382">The Mutual Fund That Ate Wall Street—Based on an Index Few People Know About</a></h3><div class="field field-name-body"><p>Vanguard&rsquo;s Total Stock Market Fund, at $1.3 trillion in assets, is a market unto itself&mdash;powered by an unassuming index called CRSP.</p>
# </div><div class="field field-name-custom-readmore"><div class="field-name-node-link"><a href="https://www.wsj.com/articles/mutual-funds-that-ate-wall-st-11638390382">Read More</a></div></div></div>
#
#   </div>
#   <div class="views-row views-row-7 views-row-odd">
#     <div class="ds-1col node node-research-item node-teaser node-odd published no-comments node-teaser view-mode-teaser clearfix">
#
#
#   <h3><a href="https://www.morningstar.com/articles/1032482/there-are-devils-in-index-methodologies-details">When It Comes to Indexes, the Devil is in the Details</a></h3><div class="field field-name-field-publication">Morningstar</div><div class="field field-name-body"><p>Indexes have broad reach, but the amount of the U.S. market&rsquo;s investable market capitalization they capture varies. Broad diversification ensures that investors have a stake in the market&rsquo;s winners and mitigates the impact of owning a lot of losers. This article describes how the CRSP Indexes seek to deliver optimal and comprehensive market exposure.</p>
# </div><div class="field field-name-custom-readmore"><div class="field-name-node-link"><a href="https://www.morningstar.com/articles/1032482/there-are-devils-in-index-methodologies-details">Read More</a></div></div></div>
#
#   </div>
#   <div class="views-row views-row-8 views-row-even views-row-last">
#     <div class="ds-1col node node-research-item node-teaser node-even published no-comments node-teaser view-mode-teaser clearfix">
#
#
#   <h3><a href="https://www.forbes.com/sites/jeffkauflin/2019/05/30/vanguard-is-now-using-blockchain-technology-to-help-manage-13-trillion-in-index-funds/?sf213544154=1#331554ef8dfe">Vanguard Is Now Using Blockchain Technology To Help Manage $1.3 Trillion In Index Funds</a></h3><div class="field field-name-field-publication">Forbes</div><div class="field field-name-body"><p>Vanguard, the 44-year-old mutual giant famous for popularizing index investing, has completed one of the most noteworthy implementations of blockchain technology for a financial institution to date.</p>
# </div><div class="field field-name-custom-readmore"><div class="field-name-node-link"><a href="https://www.forbes.com/sites/jeffkauflin/2019/05/30/vanguard-is-now-using-blockchain-technology-to-help-manage-13-trillion-in-index-funds/?sf213544154=1#331554ef8dfe">Read More</a></div></div></div>
#
#   </div>
# </div>    </div>
#
#
#
#
#
#
# </div> <div class="view view-crsp-in-the-news-in-action-items- view-id-crsp_in_the_news_in_action_items_ view-display-id-entity_view_1 view-dom-id-4bc48cb528e8f3cf5fe72ca4e6596f38">
#         <h2 class="title">Research Papers Using CRSP Data</h2>
#
#
#
#
#       <div class="view-content">
#       <div class="group-wrap group-count-2">
#   <div class="views-row views-row-1 views-row-odd views-row-first">
#     <div class="ds-1col node node-article node-teaser node-odd published no-comments node-teaser view-mode-teaser clearfix">
#
#
#   <h3><a href="https://nekrasov.people.uic.edu/Papers/Broken%20Rung%20-%20Female%20Employees%20in%20Higher-Paying%20Positions%20and%20Firm%20Performance.pdf">The Gender Position Gap and Firm Performance</a></h3><div class="field field-name-field-byline">CRSP/Compustat Merged Database</div><div class="field field-name-body"><p><strong>Author Information:</strong><br />
# 	Chuchu Liang |&nbsp;University of California, Irvine<br />
# 	Ben Lourie | University of California, Irvine<br />
# 	Alexander Nekrasov | University of Illinois at Chicago</p>
# </div><div class="field field-name-custom-readmore"><div class="field-name-node-link"><a href="https://nekrasov.people.uic.edu/Papers/Broken%20Rung%20-%20Female%20Employees%20in%20Higher-Paying%20Positions%20and%20Firm%20Performance.pdf">Read More</a></div></div></div>
#
#   </div>
#   <div class="views-row views-row-2 views-row-even">
#     <div class="ds-1col node node-article node-teaser node-even published no-comments node-teaser view-mode-teaser clearfix">
#
#
#   <h3><a href="https://www.frbsf.org/economic-research/wp-content/uploads/sites/4/Paper-5-2019-11-8-Kiku-1PM-1st-paper.pdf">Climate Change Risk</a></h3><div class="field field-name-field-byline">CRSP/Compustat Merged Database, CRSP US Stock Databases, CRSP US Treasury Database</div><div class="field field-name-body"><p><strong>Author Information:</strong><br />
# 	Ravi Bansal | Fuqua School of Business, Duke University<br />
# 	Dana Kiku | University of Illinois at Urbana-Champaign<br />
# 	Marcelo Ochoa | Federal Reserve Board</p>
# </div><div class="field field-name-custom-readmore"><div class="field-name-node-link"><a href="https://www.frbsf.org/economic-research/wp-content/uploads/sites/4/Paper-5-2019-11-8-Kiku-1PM-1st-paper.pdf">Read More</a></div></div></div>
#
#   </div>
#   <div class="views-row views-row-3 views-row-odd views-row-last">
#     <div class="ds-1col node node-article node-teaser node-odd published no-comments node-teaser view-mode-teaser clearfix">
#
#
#   <h3><a href="https://haslam.utk.edu/wp-content/uploads/drupal/sites/default/files/files/LiMaiShenYan_Corporate%20Culture%20and%20Mergers%20and%20Acquisitions_20180429.pdf">Corporate Culture and Mergers and Acquisitions: Evidence from Machine Learning</a></h3><div class="field field-name-field-byline">CRSP/Compustat Merged Database</div><div class="field field-name-body"><p><strong>Author Information:</strong><br />
# 	Kai Li |&nbsp;Sauder School of Business, University of British Columbia<br />
# 	Feng Mai | Stevens Institute of Technology<br />
# 	Rui Shen | Nanyang Business School, Nanyang Technological University<br />
# 	Xinyan Yan |&nbsp;School of Business Administration, University of Dayton</p>
# </div><div class="field field-name-custom-readmore"><div class="field-name-node-link"><a href="https://haslam.utk.edu/wp-content/uploads/drupal/sites/default/files/files/LiMaiShenYan_Corporate%20Culture%20and%20Mergers%20and%20Acquisitions_20180429.pdf">Read More</a></div></div></div>
#
#   </div>
# </div>    </div>
#
#
#
#
#
#
# </div> </div>
#
#   </div><!-- /.content -->
#
# </div><!-- /.block -->
#   </div>
#
#       </div><!-- /#main -->
#
#
#
# </div><!-- /#wrap -->
#
#       <footer id="footer" role="contentinfo">
#         <div class="bounds">
#           <div class="region region-footer">
#     <div id="block-menu-menu-footer-menu" class="block block-menu block-odd">
#
#
#   <div class="content">
#     <ul class="menu clearfix"><li class="first leaf chicago-booth mid-1657"><a href="http://www.chicagobooth.edu/" title="">Chicago Booth</a></li>
# <li class="leaf policies-statements mid-916"><a href="/policies-statements" title="">Policies &amp; Statements</a></li>
# <li class="last leaf privacy-terms-conditions mid-917"><a href="/privacy-terms-conditions" title="">Privacy Terms &amp; Conditions</a></li>
# </ul>  </div><!-- /.content -->
#
# </div><!-- /.block -->
#   </div>
#         <div class="copyright">&copy;2023 CRSP, LLC. All Rights Reserved.</div>
#         </div><!-- /bounds -->
#     </footer><!-- /#footer -->
#   <!-- Start of Async HubSpot Analytics Code -->
#   <script type="text/javascript">
#     (function(d,s,i,r) {
#       if (d.getElementById(i)){return;}
#       var n=d.createElement(s),e=d.getElementsByTagName(s)[0];
#       n.id=i;n.src='//js.hs-analytics.net/analytics/'+(Math.ceil(new Date()/r)*r)+'/11407.js';
#       e.parentNode.insertBefore(n, e);
#     })(document,"script","hs-analytics",300000);
#   </script>
# <!-- End of Async HubSpot Analytics Code -->
# </div><!-- /#page -->
#
# </body>
# </html>

# %%
#將抓下來的資料用Beautifulsoup4轉為HTML的parser
soup = BeautifulSoup(r.text,"html.parser") #將網頁資料以html.parser
sel = soup.select("h3") #***取HTML標中的 <div class="title"></div> 中的<a>標籤存入sel

# %%
#最後寫一個迴圈將爬下來的文章標題印出來
for s in sel:
    print(s.text)
# Out:
# Douglas Diamond wins Nobel Prize for research on banks and financial crises
# CBOT Closing Bell Ceremony - September 12
# Why Vanguard Value Index Is a Good Investment Today
# Best value ETFs
# Passive ETFS Hit by Billion-Dollar Rebalancing Costs
# The Mutual Fund That Ate Wall Street—Based on an Index Few People Know About
# When It Comes to Indexes, the Devil is in the Details
# Vanguard Is Now Using Blockchain Technology To Help Manage $1.3 Trillion In Index Funds
# The Gender Position Gap and Firm Performance
# Climate Change Risk
# Corporate Culture and Mergers and Acquisitions: Evidence from Machine Learning
